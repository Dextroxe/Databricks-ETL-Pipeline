# %% [markdown]
# # work1
#
# ## load a sample csv file in volume
#
# ### create a extract notebook
#  should have logic to,
#   read csv file to dataframe,
#   handle duplicate column
#   encrypt sensitive data
#   create partition column
#   write df to bronze table in UC with partition
#
# ### create a transform notebook
#  should have logic to,
#   read the stored bronze table to df
#   handle null values in the df
#   explode the struct/array type columns
#   create new column (min 2) of you own logic
#   write the result df to silver table in UC with partition
#
# ### create a load notebook
#  should have logic to,
#   perform aggregations of any type (grouping and getting sum/count)
#   use window function
#   use join
#   write the result df to gold table in UC with partition (if required create two/more tables)
#
# ### create a job
#  should have,
#   three tasks extract/transform/load, which runs the about created notebook
#   add parameters, schedule, notification (if needed)

# %% [markdown]
# ### create a config Notebook,
#  should contains catalog, schema, table name (and any other infos)
#   this notebook should be run at the first cell of extract, transform, load notebook and get variable from there
